# %%
from pathlib import Path

from ultralytics import YOLO
import torch

# %%
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# CUDA: True
# NVIDIA GeForce RTX 4060 Ti

# %%
import sys

sys.path.insert(0, str(Path.cwd().resolve().parent))
import src.config as cfg

DATA_YAML = cfg.DATA_YAML

# %%
model = YOLO("yolo26n.pt")

# %%
results = model.train(
    data=DATA_YAML,
    epochs=30,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.75  Python-3.12.13 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    242736  ultralytics.nn.modules.head.Detect           [4, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,505,360 parameters, 2,505,360 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 31.810.3 MB/s, size: 242.7 KB)
# train: Scanning C:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\train\labels... 1577 images, 379 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1577/1577 457.7it/s 3.4s0.0s
# train: New cache created: C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\train\labels.cache
# val: Fast image access  (ping: 0.20.0 ms, read: 25.611.1 MB/s, size: 312.6 KB)
# val: Scanning C:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\val\labels... 395 images, 102 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 395/395 225.8it/s 1.7s.1s
# val: New cache created: C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\val\labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.55G      1.382      7.307   0.004896         20        640: 100% ━━━━━━━━━━━━ 99/99 3.6it/s 27.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.1it/s 2.6s0.2s
#                    all        395        494      0.876     0.0982      0.231      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.68G      1.325      5.135   0.004826         26        640: 100% ━━━━━━━━━━━━ 99/99 4.0it/s 24.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.1it/s 2.1s0.2s
#                    all        395        494      0.494      0.472      0.452      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.68G      1.334      3.841    0.00523         20        640: 100% ━━━━━━━━━━━━ 99/99 3.9it/s 25.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.5it/s 2.4s0.2s
#                    all        395        494      0.634      0.461      0.536      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.68G      1.294      2.698   0.004913         24        640: 100% ━━━━━━━━━━━━ 99/99 4.1it/s 24.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.2it/s 2.1s0.2s
#                    all        395        494      0.692      0.576      0.642      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      2.68G       1.32      2.069   0.005031         25        640: 100% ━━━━━━━━━━━━ 99/99 4.2it/s 23.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.9it/s 2.2s0.2s
#                    all        395        494      0.669      0.611      0.672      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      2.68G      1.276      1.768   0.004818         27        640: 100% ━━━━━━━━━━━━ 99/99 4.0it/s 24.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.4it/s 2.0s0.2s
#                    all        395        494      0.695      0.625      0.673      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      2.68G      1.282      1.559   0.004756         14        640: 100% ━━━━━━━━━━━━ 99/99 4.3it/s 23.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.2s0.2s
#                    all        395        494      0.727       0.63      0.727      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      2.68G      1.241      1.401   0.004452         21        640: 100% ━━━━━━━━━━━━ 99/99 4.5it/s 21.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.9it/s 2.2s0.2s
#                    all        395        494      0.765      0.632      0.726      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      2.68G       1.24      1.346   0.004285         22        640: 100% ━━━━━━━━━━━━ 99/99 4.3it/s 23.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.4it/s 2.4s0.2s
#                    all        395        494      0.804      0.674      0.766      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      2.68G      1.196       1.25   0.004387         26        640: 100% ━━━━━━━━━━━━ 99/99 4.1it/s 24.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.6it/s 2.8s0.2s
#                    all        395        494      0.779      0.669       0.76      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      2.68G      1.187      1.213   0.004368         26        640: 100% ━━━━━━━━━━━━ 99/99 4.1it/s 24.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.9it/s 2.2s0.2s
#                    all        395        494      0.846      0.634       0.76       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      2.68G      1.146      1.101   0.004184         27        640: 100% ━━━━━━━━━━━━ 99/99 4.5it/s 21.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.5it/s 2.0s0.1s
#                    all        395        494      0.857      0.672      0.793      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      2.68G      1.137      1.061   0.004057         24        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 21.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.5it/s 2.0s0.2s
#                    all        395        494      0.849      0.683      0.806      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      2.68G      1.132      1.063   0.004039         26        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 21.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.6it/s 2.0s0.1s
#                    all        395        494      0.804      0.714      0.802      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      2.68G      1.084      1.006   0.003842         20        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 21.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.6it/s 2.0s0.2s
#                    all        395        494      0.818      0.722      0.819      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      2.68G      1.096     0.9801   0.003815         19        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 21.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.5it/s 2.0s0.1s
#                    all        395        494      0.832       0.73      0.831      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      2.68G      1.117     0.9445   0.003804         24        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 21.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.6it/s 2.0s0.1s
#                    all        395        494      0.794      0.743       0.82      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      2.68G      1.046     0.8869   0.003566         29        640: 100% ━━━━━━━━━━━━ 99/99 4.6it/s 21.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.6it/s 2.0s0.1s
#                    all        395        494      0.832      0.758      0.842      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      2.68G      1.036     0.8761   0.003512         22        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 21.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.6it/s 2.0s0.1s
#                    all        395        494      0.838      0.739      0.846      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      2.68G      1.043     0.8487   0.003537         18        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 21.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.5it/s 2.0s0.1s
#                    all        395        494      0.855      0.737       0.85      0.657
# Closing dataloader mosaic

# %%
results = model.train(
    data=DATA_YAML,
    epochs=30,
    imgsz=640,
    batch=16,
    workers=0
)
# Out:
# Ultralytics 8.4.75  Python-3.12.13 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    242736  ultralytics.nn.modules.head.Detect           [4, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,505,360 parameters, 2,505,360 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 288.368.7 MB/s, size: 242.7 KB)
# train: Scanning C:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\train\labels.cache... 1577 images, 379 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1577/1577  0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 371.676.7 MB/s, size: 312.6 KB)
# val: Scanning C:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\val\labels.cache... 395 images, 102 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 395/395  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train-2\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train-2
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.56G      1.289      7.385    0.00507         19        640: 100% ━━━━━━━━━━━━ 99/99 1.8it/s 55.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.1it/s 6.1s0.5s
#                    all        395        494      0.635     0.0981      0.233      0.169
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.68G      1.271       5.26   0.005006         25        640: 100% ━━━━━━━━━━━━ 99/99 1.9it/s 51.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.2it/s 5.9s0.5s
#                    all        395        494      0.551      0.408       0.44      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.68G      1.345       3.81   0.005097         17        640: 100% ━━━━━━━━━━━━ 99/99 1.9it/s 51.6s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.3it/s 5.8s0.5s
#                    all        395        494      0.607      0.515      0.559      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.68G      1.358      3.051   0.005071         25        640: 36% ━━━━──────── 36/99 2.5it/s 18.7s<25.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 results = model.train(
#       2     data=DATA_YAML,
#       3     epochs=30,
#       4     imgsz=640,
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\ultralytics\engine\model.py:792, in Model.train(self, trainer, **kwargs)
#     789     self.trainer.model = self.trainer.get_model(weights=weights, cfg=self.model.yaml)
#     790     self.model = self.trainer.model
# --> 792 self.trainer.train()
#     793 # Update model and cfg after training
#     794 if RANK in {-1, 0}:
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\ultralytics\engine\trainer.py:246, in BaseTrainer.train(self)
#     243             ddp_cleanup(self, str(file))
#     245 else:
# --> 246     self._do_train()
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\ultralytics\engine\trainer.py:423, in BaseTrainer._do_train(self)
#     421     pbar = TQDM(enumerate(self.train_loader), total=nb)
#     422 self.tloss = None
# --> 423 for i, batch in pbar:
#     424     self.run_callbacks("on_train_batch_start")
#     425     # Warmup
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\ultralytics\utils\tqdm.py:350, in TQDM.__iter__(self)
#     347     raise TypeError("'NoneType' object is not iterable")
#     349 try:
# --> 350     for item in self.iterable:
#     351         yield item
#     352         self.update(1)
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\ultralytics\data\build.py:82, in InfiniteDataLoader.__iter__(self)
#      80 """Create an iterator that yields indefinitely from the underlying iterator."""
#      81 for _ in range(len(self)):
# ---> 82     yield next(self.iterator)
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\ultralytics\data\base.py:397, in BaseDataset.__getitem__(self, index)
#     395 def __getitem__(self, index: int) -> dict[str, Any]:
#     396     """Return transformed label information for given index."""
# --> 397     return self.transforms(self.get_image_and_label(index))
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\ultralytics\data\augment.py:158, in Compose.__call__(self, data)
#     141 """Apply a series of transformations to input data.
#     142
#     143 This method sequentially applies each transformation in the Compose object's transforms to the input data.
#    (...)    155     >>> transformed_data = compose(input_data)
#     156 """
#     157 for t in self.transforms:
# --> 158     data = t(data)
#     159 return data
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\ultralytics\data\augment.py:54, in BaseTransform.__call__(self, labels)
#      45 """Apply transformation to labels dict.
#      46
#      47 Args:
#    (...)     51     (dict): Transformed labels dictionary.
#      52 """
#      53 params = self.get_params(labels)
# ---> 54 labels = self.apply_image(labels, params)
#      55 labels = self.apply_instances(labels, params)
#      56 labels = self.apply_semantic(labels, params)
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\ultralytics\data\augment.py:1472, in RandomHSV.apply_image(self, labels, params)
#    1469     lut_sat[0] = 0  # prevent pure white changing color, introduced in 8.3.79
#    1471     hue, sat, val = cv2.split(cv2.cvtColor(img, cv2.COLOR_BGR2HSV))
# -> 1472     im_hsv = cv2.merge((cv2.LUT(hue, lut_hue), cv2.LUT(sat, lut_sat), cv2.LUT(val, lut_val)))
#    1473     cv2.cvtColor(im_hsv, cv2.COLOR_HSV2BGR, dst=img)  # no return needed
#    1474 return labels
#
# KeyboardInterrupt:

# %%
results = model.train(
    data=DATA_YAML,
    epochs=30,
    imgsz=640,
    batch=16,
    close_mosaic=0
)
# Out:
# Ultralytics 8.4.75  Python-3.12.13 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=0, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train-3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    242736  ultralytics.nn.modules.head.Detect           [4, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,505,360 parameters, 2,505,360 gradients, 5.8 GFLOPs
#
# Transferred 708/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 1785.7448.4 MB/s, size: 247.6 KB)
# train: Scanning C:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\train\labels.cache... 1577 images, 379 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1577/1577  0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 1429.5256.1 MB/s, size: 315.0 KB)
# val: Scanning C:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\data\minecraft_mobs\minecraft_mobs_yolo\val\labels.cache... 395 images, 102 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 395/395  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train-3\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train-3
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.82G      1.276      2.595   0.004461         20        640: 100% ━━━━━━━━━━━━ 99/99 4.0it/s 24.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.7it/s 1.9s0.1s
#                    all        395        494      0.751      0.546      0.648      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.82G      1.232        2.2   0.004554         26        640: 100% ━━━━━━━━━━━━ 99/99 4.5it/s 21.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.6it/s 2.3s0.2s
#                    all        395        494      0.742      0.487      0.611      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.82G       1.23      1.943   0.004716         20        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 21.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.2it/s 2.1s0.2s
#                    all        395        494       0.73      0.575      0.658      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.82G      1.209      1.625    0.00454         24        640: 100% ━━━━━━━━━━━━ 99/99 4.4it/s 22.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.1it/s 2.1s0.2s
#                    all        395        494      0.689      0.621      0.695      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      2.82G       1.26        1.5   0.004766         25        640: 100% ━━━━━━━━━━━━ 99/99 4.4it/s 22.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.3it/s 2.1s0.2s
#                    all        395        494      0.728      0.651      0.718      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      2.82G      1.199      1.376   0.004447         27        640: 100% ━━━━━━━━━━━━ 99/99 4.6it/s 21.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.5it/s 2.0s0.1s
#                    all        395        494      0.756      0.608      0.715      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      2.82G      1.216      1.317   0.004484         14        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 20.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.0it/s 1.8s0.1s
#                    all        395        494       0.78      0.667      0.757      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      2.82G      1.177      1.193   0.004144         21        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 21.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.3it/s 2.1s0.2s
#                    all        395        494      0.824      0.669      0.769      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      2.82G      1.208      1.173   0.004192         22        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.2it/s 2.1s0.2s
#                    all        395        494        0.8      0.681      0.788      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      2.82G      1.153      1.103   0.004147         26        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 20.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.7it/s 2.0s0.1s
#                    all        395        494      0.852      0.706        0.8      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      2.82G      1.136        1.1   0.004125         26        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.7it/s 1.9s0.1s
#                    all        395        494      0.814      0.657      0.791      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      2.82G      1.086      1.015   0.003892         27        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.8it/s 1.9s0.1s
#                    all        395        494      0.825      0.701      0.814      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      2.82G      1.082     0.9686   0.003892         24        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.9it/s 1.9s0.1s
#                    all        395        494      0.858      0.722      0.829      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      2.82G      1.084     0.9747   0.003854         26        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.9it/s 1.9s0.1s
#                    all        395        494      0.819      0.765      0.831      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      2.82G       1.08     0.9251   0.003936         20        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.1it/s 1.8s0.1s
#                    all        395        494      0.838      0.726      0.824      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      2.82G      1.065     0.9029   0.003677         19        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.9it/s 1.9s0.1s
#                    all        395        494      0.824      0.753      0.829      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      2.82G       1.07     0.8787   0.003496         24        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.0it/s 1.9s0.1s
#                    all        395        494      0.885      0.714      0.842      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      2.82G      1.009     0.8062   0.003388         29        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.4it/s 1.8s0.1s
#                    all        395        494      0.796      0.793      0.849      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      2.82G      1.006     0.7941    0.00339         22        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.0it/s 1.8s0.1s
#                    all        395        494      0.859       0.76      0.853      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      2.82G     0.9919     0.7824   0.003341         18        640: 100% ━━━━━━━━━━━━ 99/99 4.6it/s 21.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.0it/s 1.9s0.1s
#                    all        395        494      0.908      0.732       0.86      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      2.82G     0.9796     0.7722   0.003452         20        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.8it/s 1.9s0.1s
#                    all        395        494      0.865      0.775      0.859      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      2.82G     0.9742     0.7724   0.003173         17        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.2it/s 1.8s0.1s
#                    all        395        494      0.838      0.777      0.858      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      2.82G     0.9741      0.755   0.003164         15        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.8it/s 1.9s0.1s
#                    all        395        494      0.871      0.787      0.869       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      2.82G       0.97     0.7297   0.003258         18        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 20.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.0it/s 1.9s0.1s
#                    all        395        494      0.894      0.756      0.866       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      2.82G     0.9628     0.7403   0.003206         13        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.1it/s 1.8s0.1s
#                    all        395        494      0.929      0.747      0.876      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      2.82G     0.9338     0.7143   0.002918         17        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.2it/s 1.8s0.1s
#                    all        395        494      0.897      0.768      0.871      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.82G     0.9192     0.6969   0.003152         20        640: 100% ━━━━━━━━━━━━ 99/99 4.7it/s 20.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.1it/s 1.8s0.1s
#                    all        395        494      0.831      0.805      0.864      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      2.82G     0.9099      0.715   0.002878         19        640: 100% ━━━━━━━━━━━━ 99/99 4.9it/s 20.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.7it/s 1.9s0.1s
#                    all        395        494      0.861      0.799      0.872      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      2.82G     0.8928     0.6706   0.002785         23        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.0it/s 1.9s0.1s
#                    all        395        494      0.861      0.797      0.874      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      2.82G     0.9082     0.7142    0.00284         19        640: 100% ━━━━━━━━━━━━ 99/99 4.8it/s 20.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.3it/s 1.8s0.1s
#                    all        395        494      0.891      0.775      0.873        0.7
#
# 30 epochs completed in 0.197 hours.
# Optimizer stripped from C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train-3\weights\last.pt, 5.4MB
# Optimizer stripped from C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train-3\weights\best.pt, 5.4MB
#
# Validating C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train-3\weights\best.pt...
# Ultralytics 8.4.75  Python-3.12.13 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# YOLO26n summary (fused): 122 layers, 2,375,616 parameters, 0 gradients, 5.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.3it/s 2.5s0.2s
#                    all        395        494      0.884      0.779      0.872        0.7
#                creeper         74         84      0.845      0.738       0.84      0.682
#               skeleton        136        154       0.91      0.792      0.871      0.716
#                 spider         80         92      0.886      0.847      0.916      0.738
#                 zombie        123        164      0.896      0.738      0.861      0.664
# Speed: 0.2ms preprocess, 1.3ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to C:\Users\pedro\OneDrive\Documentos\programao\eletiva-leomar\YOLOCraft\notebooks\runs\detect\train-3

# %%
import pandas as pd

df = pd.read_csv("runs/detect/train-3/results.csv")
print(df.tail())
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 25     26  617.131         0.93384         0.71429         0.00292
# 26     27  640.570         0.91925         0.69693         0.00315
# 27     28  663.518         0.90991         0.71503         0.00288
# 28     29  686.655         0.89277         0.67062         0.00278
# 29     30  709.622         0.90818         0.71422         0.00284
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 25               0.89676            0.76806           0.87144
# 26               0.83052            0.80502           0.86417
# 27               0.86137            0.79851           0.87193
# 28               0.86143            0.79711           0.87376
# 29               0.89080            0.77505           0.87253
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 25              0.69430       0.85174       0.77897       0.00466  0.000219
# 26              0.68866       0.85258       0.79455       0.00469  0.000178
# 27              0.69434       0.84082       0.78250       0.00454  0.000136
# 28              0.69592       0.84013       0.78545       0.00456  0.000095
# 29              0.69983       0.83312       0.76582       0.00447  0.000054
#
#       lr/pg1    lr/pg2
# 25  0.000219  0.000219
# 26  0.000178  0.000178
# 27  0.000136  0.000136
# 28  0.000095  0.000095
# 29  0.000054  0.000054

# %%
metrics = results.val()
print(f"\nmAP50:    {metrics.box.map50:.4f}")
print(f"mAP50-95: {metrics.box.map:.4f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 metrics = results.val()
#       2 print(f"\nmAP50:    {metrics.box.map50:.4f}")
#       3 print(f"mAP50-95: {metrics.box.map:.4f}")
#
# File c:\Users\pedro\OneDrive\Documentos\programação\eletiva-leomar\YOLOCraft\.venv\Lib\site-packages\ultralytics\utils\__init__.py:291, in SimpleClass.__getattr__(self, attr)
#     289 """Provide a custom attribute access error message with helpful information."""
#     290 name = self.__class__.__name__
# --> 291 raise AttributeError(f"'{name}' object has no attribute '{attr}'. See valid attributes below.\n{self.__doc__}")
#
# AttributeError: 'DetMetrics' object has no attribute 'val'. See valid attributes below.
# Utility class for computing detection metrics such as precision, recall, and mean average precision (mAP).
#
#     Attributes:
#         names (dict[int, str]): A dictionary of class names.
#         box (Metric): An instance of the Metric class for storing detection results.
#         speed (dict[str, float]): A dictionary for storing execution times of different parts of the detection process.
#         stats (dict[str, list]): A dictionary containing lists for true positives, confidence scores, predicted classes,
#             target classes, and target images.
#         nt_per_class: Number of targets per class.
#         nt_per_image: Number of targets per image.
#
#     Methods:
#         update_stats: Update statistics by appending new values to existing stat collections.
#         process: Process predicted results for object detection and update metrics.
#         clear_stats: Clear the stored statistics.
#         keys: Return a list of keys for accessing specific metrics.
#         mean_results: Calculate mean of detected objects & return precision, recall, mAP50, and mAP50-95.
#         class_result: Return the result of evaluating the performance of an object detection model on a specific class.
#         maps: Return mean Average Precision (mAP) scores per class.
#         fitness: Return the fitness of box object.
#         ap_class_index: Return the average precision index per class.
#         results_dict: Return dictionary of computed performance metrics and statistics.
#         curves: Return a list of curves for accessing specific metrics curves.
#         curves_results: Return a list of computed performance metrics and statistics.
#         summary: Generate a summarized representation of per-class detection metrics as a list of dictionaries.
